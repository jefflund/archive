# %%
import collections

import numpy as np
import tensorflow as tf
from tensorflow.python.layers import core as layers_core
from tensorflow.python.ops.rnn_cell_impl import _linear, RNNCell

# %%
# Global variables are evil...
num_epochs = 1000
print_interval = 100
batch_size = 50
sequence_length = 50
state_dim = 128
num_layers = 2

# %%
class GRUCell(RNNCell):

    def __init__(self, num_units, reuse=None):
        super(GRUCell, self).__init__(_reuse=reuse)
        self._num_units = num_units

    @property
    def state_size(self):
        return self._num_units

    @property
    def output_size(self):
        return self._num_units

    def __call__(self, inputs, state):
        with tf.variable_scope('update'):
            z_t = tf.nn.sigmoid(_linear([inputs, state], self._num_units, True))
        with tf.variable_scope('reset'):
            r_t = tf.nn.sigmoid(_linear([inputs, state], self._num_units, True))
        with tf.variable_scope('output'):
            h_t = tf.nn.tanh(z_t * state + (1 - z_t) * _linear([inputs, r_t * state], self._num_units, True))

        return h_t, h_t

# %%
# While trying to understand TextLoader I refactored a bit
def load_data(input_file):
    with open(input_file) as f:
        data = f.read()

    chars = collections.Counter(data)
    chars = sorted(chars, key=chars.get, reverse=True)
    vocab = {v: i for i, v in enumerate(chars)}

    num_batches = len(data) // (batch_size * sequence_length)
    xs = list(map(vocab.get, data))[:num_batches * batch_size * sequence_length]
    ys = xs[1:] + xs[:1]
    xs = np.split(np.reshape(xs, (batch_size, -1)), num_batches, 1)
    ys = np.split(np.reshape(ys, (batch_size, -1)), num_batches, 1)
    batches = list(zip(xs, ys))

    return vocab, chars, batches

# %%
# Yup...I just put my whole stinkin lab in a single function so I could run it
# on multiple input files...
def do_lab8(input_file, prime):
    # Get the data
    vocab, chars, batches = load_data(input_file)
    vocab_size = len(vocab)
    
    # Allow multiple calls to do_lab8
    tf.reset_default_graph()

    # Training inputs/targets
    in_ph = tf.placeholder(tf.int32, [batch_size, sequence_length], name='inputs')
    targ_ph = tf.placeholder(tf.int32, [batch_size, sequence_length], name='targets')
    in_onehot = tf.one_hot(in_ph, vocab_size, name='intput_onehot')
    inputs = tf.split(in_onehot, sequence_length, axis=1)
    inputs = [tf.squeeze(input_, [1]) for input_ in inputs]
    targets = tf.split(targ_ph, sequence_length, axis=1)
    targets = tf.reshape(tf.stack(targets), [sequence_length, batch_size])

    # Create network
    # cells = [tf.contrib.rnn.BasicRNNCell(state_dim) for _ in range(num_layers)]
    cells = [GRUCell(state_dim) for _ in range(num_layers)]
    cells =  tf.contrib.rnn.MultiRNNCell(cells)
    linear = layers_core.Dense(vocab_size, use_bias=True)

    # Decoder and output for training
    initial_state = cells.zero_state(batch_size, tf.float32)
    helper = tf.contrib.seq2seq.TrainingHelper(inputs, [sequence_length] * batch_size, time_major=True)
    decoder = tf.contrib.seq2seq.BasicDecoder(cells, helper, initial_state, output_layer=linear)
    outputs, final_state, _ = tf.contrib.seq2seq.dynamic_decode(decoder, output_time_major=True)
    logits = outputs.rnn_output

    # Optimize training loss
    loss = tf.contrib.seq2seq.sequence_loss(logits, targets, tf.ones([batch_size, sequence_length]))
    loss = tf.reduce_mean(loss)
    train = tf.train.AdamOptimizer().minimize(loss)
    summary = tf.summary.scalar('loss', loss)

    # Sampling inputs
    s_in_ph = tf.placeholder(tf.int32, [1], name='s_inputs')
    s_in_onehot = tf.one_hot(s_in_ph, vocab_size, name='s_intput_onehot')
    s_inputs = tf.split(s_in_onehot, 1, axis=1)

    # Sampling decoder and output
    s_initial_state = cells.zero_state(1, tf.float32)
    s_helper = tf.contrib.seq2seq.TrainingHelper(s_inputs, [1], time_major=True)
    s_decoder = tf.contrib.seq2seq.BasicDecoder(cells, s_helper, s_initial_state, output_layer=linear)
    s_outputs, s_final_state, _ = tf.contrib.seq2seq.dynamic_decode(s_decoder, output_time_major=True)
    s_probs = tf.nn.softmax(s_outputs.rnn_output)

    sess = tf.Session()
    sess.run(tf.global_variables_initializer())

    def train_epoch():
        state = sess.run(initial_state)
        for x, y in batches:
            feed = {in_ph: x, targ_ph: y}
            for k, s in enumerate(initial_state):
                feed[s] = state[k]
            _, state = sess.run([train, final_state], feed)

    def sample(sample_size, prime):
        state = sess.run(s_initial_state)

        for char in prime[:-1]:
            feed = {s_in_ph: np.ravel(vocab[char]).astype(np.int32)}
            for i, s in enumerate(s_initial_state):
                feed[s] = state[i]
            state = sess.run(s_final_state, feed)

        result = prime
        char = prime[-1]
        for _ in range(sample_size):
            feed = {s_in_ph: np.ravel(vocab[char]).astype(np.int32)}
            for i, s in enumerate(s_initial_state):
                feed[s] = state[i]
            probs, state = sess.run([s_probs, s_final_state], feed)

            # sample = np.argmax(probs[0][0])
            sample = np.random.choice(vocab_size, p=probs[0][0])
            pred = chars[sample]
            result += pred
            char = pred

        return result

    # Train the network, ocassionaly printing a sample
    print('Training on {}'.format(input_file))
    for epoch in range(num_epochs):
        train_epoch()
        if epoch % print_interval == 0:
            print('{} {}\n'.format(epoch, sample(150, prime)))

    # Generate 15 samples from trained network
    print('Samples for {}'.format(input_file))
    for i in range(15):
        print(i, sample(300, prime))

# %%
# Required alma
do_lab8('alma.txt', 'And ')
# Out:
# Training on alma.txt
# 0 And oPther hesondt ha ming sfall omd lot nocr te tian; and hal th thit mand he delpdlim word
#  wesp anauvn thot cwiur ln tha such ypy te the bhereror pfhe
#
# 100 And the city of Ammonihah.
#
#  And it came to pass that when the Lamanites say, it was the victory; and they were foop.
#
#  And the reign of Nehorsh-led after
#
# 200 And now then she said unto them: What ye shall go against Zerohi--Chy return of God were called their number over the people of Nephi, no the wicked; and
#
# 300 And became before the city, to Zeezrom of long over the sword, and which is the land of Noah might be praised all this, Gid, on his brethren.
#
#  But it cam
#
# 400 And because of their desires, insomuch that we desire to be no thought bod, by their camp to manibele? Yea, they were not provoce he will I trust his Son,
#
# 500 And now, I have said for they were degreed them about more power unto all have the brother of Ammoron, and do might reas Lehi came nothing by the hearts o
#
# 600 And not the law of Moronity of their brethren, the Lamanites had taken frum insomuch that they would not hear his words; for on his niglt even to hain a s
#
# 700 And behold, we are a righteous people, if there was no law against as juitss is exceedingly, compand dim, throught into the world to possiss throughout al
#
# 800 And also: What grain, then will overpower the dail--torruntion--not on groutent repentance unto himself; and the resurrection; and they came over to the c
#
# 900 And beheld, that we were full of our city, should bring forth fruit unto us, as ye have been ruspoof the way that ye have much see; for ye may light any d
#
# Samples for alma.txt
# 0 And behold, the Lamanites had taken them to their words, because of the power of Alma, or our God making uptil with our faith, that perish, and also all the mightion and afflictions and joy. Wo unto, cause you were zeal unto me shall be caused to dispredion the many his words--Gid, who knowled them from
# 1 And now merce and executed they were angers and also highly greaters are meet down the walls--my soul at the law should be destroyed, were angry with them, not understand thy brother: kne salver and laying this great and last such contending, according to his desires.
#
#  And behold, his army for the plan
# 2 And boubehe; they gain for the other is generatier in the land of Jude. Behorsions, and all his words he determinint. And thus it is in the destruction of the prihines which ye depared to tepert by Ammon, they servants did see the blessing that she desires that he pewert to an exceeding the resurrection
# 3 And Lehi with whomehe all consigned to harres of peace, Nepurt the freenom rokn unto them: WYe were extedmles which he had taken, and also Amulek juitguravey in the more were desperil unto him.
#
#  And they went by their lands, and the loss also blessed art thou bes tribulations had heard these departed a
# 4 And now it came to pass that when the whoredomst the people of Ammon, of Alma dem host in the graves of his angels.
#
#  And now it came to pass that she he was also punished; doy and drove his word, and led by the hearts of the Lamanites make the chief shith that they might to two day, ye mo; and the peop
# 5 And now it came to pass that the Nephites in wating the word by as the house understend his people with Gide it no thoush was as greatless not; therefore it is began to Jacob, wast might remain unto many works dided again to remember, I say unto all of God, of his men were fallen.
#
#  And he said: Yea, I
# 6 And moreher to come to Zarahemla.
#
#  And behold the Lord will all time they began to be the cause of my country, or cut into the west secret could abond even as a sheep have fladoned of the Lamanites for more of the land of Middoni. And now, my son, see that ye will spare your flocks; and this because he
# 7 And beheld, God, their villages, save ye not prepared; and at I he went in forth all of nighe; for ye may gather together, and also sent among the Lamanites over the losg ranger, came aboye, there was on the eward of bondage.
#
#  And the broother to the righteous to come unto you, I know that the good or
# 8 And moreher, Alma, and also he began to assemble merciful unto me and come against the Nephites as they are executed the Son of God.
#
#  And this is my sins, for they are more guven or rotten be retautiouth is marchen, and made king the spirit of grant with his army which I go to the land of Nephi; yea, i
# 9 And those groth, and be by any ware, they were astonished into a cornge for recouns of the Spirit of God which the words was their chief lyinguan powert of God.
#
#  And and his forever, that which is body in inconwisher they were about to pour of the destruction of those who sought to slay him in preservi
# 10 And now merce and enter their power, and in his exrrattered at the last day and prayett our steading lift their received in unbell shall ye shall not suffer all manner of ware will be lidds adony trosences which we did not hear all ye have redeem and light, and call on his epistle unto them concerning t
# 11 And now is exceedingly rejoice before God.
#
#  Amulacieding the desire of Amalickiah, and they did fall at their weaping of truly joine.
#
#  And ye were encereing God.
#
#  And the people concerning the coming of CGrist that Great hards of your faith which I have obtained them out of bost, and also the work of
# 12 And this back unto them coveralled his people? O joy again to destroy the church of God any walls.
#
#  And it came to pass that Amalickiah were netuly curis reni them at the city of Nephihah, who frone many which is in seen, behold, the Lord guilted, and that a rest; a time evil up Ammon, and his march to
# 13 And now it came to pass that in the voice of the movered of God, by our loves were said: Then whether it should in all his chacunds year--The prought not unded up there they began to wear with God.
#
#  Now wies come in unto should make it nethills, and thus they were met these live art many homes upon the
# 14 And Jesuret repentent of our storite of my count.
#
#  Yea, we are written until here can take a punishment.
#
#  I say unto you, my beloved brethren, they believed in the strength of the Lord, by the mouth of the Lord in finister pyiters that the sons of Pahoran's army of the Nephites.
#
#  And thousands cast y

# %%
# Using the text of Beowulf. For reference, here are the first few lines of the poem:
# So. The Spear-Danes in days gone by
# And the kings who ruled them had courage and greatness.
# We have heard of those princes’ heroic campaigns.
# There was Shield Sheafson, scourge of many tribes,
# A wrecker of mead-benches, rampaging among foes.
# This terror of the hall-troops had come far.
# A foundling to start with, he would flourish later on
# As his powers waxed and his worth was proved.
# In the end each clan on the outlying coasts
# Beyond the whale-road had to yield to him
# And begin to pay tribute. That was one good king.
do_lab8('beowulf.txt', '\n')
# Out:
# Training on beowulf.txt
# 0
# “lrI xf ahiyupnri n .renwa antelt Ie .  lh mrma :h ctsa
# asTdte   aadrhehn Ool
# a
# abe ddufgtii keiaeoiit eet h w ytbad oel
# gty ehIk tt,swo.fycoonteee
#
# 100
# To but the for, in God his hands
# yor for rule a some meamurfiend.
# When the bravely stead-rated have inershepe
# Are down that wane, he will be his kept
#
# 200
# A fure. They wasted with his swar.
# So iendered lookout atiling to read
# And of his lair outsight battle. The hall things to be pleaned the Danes
# Us und
#
# 300
# When they had told with a beriesh of mannce
# About the Soutton alther walted
# Had go yours each threatened layt
# And eached a burning ones the sea-led hi
#
# 400
# Had breaths and gent, the strain-haired troop
# Down to eaped who rule and flung his owe, he suddged,
# A were armourd in the mound. No man as the trust.
#
#
# 500
# Where the weapon,
# With a quarters.  He gasher of mank
# The gold life or pail in the mome and laf crow
#  Unferring was bestow lie.
# As a swimmen, Having w
#
# 600
# Swede your place acolness, de not well king
# Water until the bene, the set to ush them well king,
# Grente tell the safe of mest gond,
# No rece, no brouch
#
# 700
# So that the greater vanty to their needed
# The old recerved and hard things thered
# As long as ran on the ragon as I what
# Theep the gold gripping trave.
#
# 800
# Of Beowulf’s sleep have
# Worquing glibbet wise you avenged
# With the graw winter sent
# To before so peet kits presected man endurieve.
# But withouk polet
#
# 900
# And the king’s sword, shore, it would distribut,
# Until from down to his life.
# She famely to retate, my lord, to King Hygelac’s deed
# To the brave sword
#
# Samples for beowulf.txt
# 0
# No sword blade sent on the obvious, earlier:
# Order twome the gaid and dappring on the hall.
# Then march and kindmsing sat,
# Had feer her me, we keening glide bright,
# When he warrior the viceiso went down
# Quagond their warrior melished and fury.
# He could long by by ence
# For his neguced, sade. I mayy br
# 1
# A feud be it floweres both sides off.
# The moors, humiliation, then heaved: itwises to him
# And soon all when monn byhered into pridiny,
# Grendel was driven with band’s peace,
# Faightred in the young his evil day
# Tour companing tell things to Denes again.
# Nowe fortemved So the mead-hall her Frunic noe
# A
# 2
# Noters, moored the meshage, last was over
# Over the earth-bounnet actoust up wave to them with. The campal this atterders and carried
# All connected in other sway well alifoush
# Peens of flank in father
# And help togethes acoons managed
# For a lord of the disting, better on the you, blade surved
# From the
# 3
# No sword blade sent on the better was for well,
# Heoroged in the men of worth
# Theop harbered the men whet Geatlay.
# Have Got well us an hearstoned an heart
# Wrethed the gaven;
#  No matters
# As companies have to his not.
# Auciest time to the God-curn by my gran
# As again of the rich and hands and landed
# The
# 4
# No sword blade sent him to his life.
# Nobyed in marrian of defeguined water,
# He pitich encounced places
# So they weep up out in that powsrant
# To tall shieting thane on the world
# Gay in Grendel, land stood up faro,
# The glory of my ackop in the horizon,
# Lesed the vener his sleep.
# Hygelac’s kinsman kept
# 5
# A friend of betwing that my people
# And beckeder. The Geat nation
# A day; he welcomest, like the king in the menate,
# A have ton. No stayed
# Had staller or mail-shrow, their trualding,
# He was the story goes
# Sfiting he did Unferring. It was the blame.
# Gefrow mother, to dead now that boasts,
# Remoish clear
# 6
# She was uscan of those part, then on their flesh. Depter, to nothing blades,
# The face of throw, no oneaged
# And recenged and found we stalted Grendel
# Helper was quickly bloodiant to taklind.
# His world. He ancient gold, wete struck
# Against a lufked his lord in rust,
# Before the foundribed rew; ic is mo
# 7
# No swood-thin her over we see
# Will conjue to faces. He and stalaged lord
# And seased in his own sons,
#  af to every
# Came frother by a force often its mate,
# Immacishs to gold distall were held his hearts:
# Me ancestres. OppleaLuce wast.
# He was a hutted the enemy out
# That I knewed on each of whole the wa
# 8
# Of things abando neiged and burge
# Of where their line, uppout. Let killed Hygelac’s Frannled;
# They what Beowulf and heavy that lane
# Insty seasomed, a weapont.
# He wonstor a deading age,
# Forged out to the serface and limmed forth
# Onersh from ondead-hose tod withis taken
# And heroly gusplayed, Grendel a
# 9
# A feud begin to the deceased,
# Earen the stronger to get anticg
# Ender hand. I knewed him.
# Hyopliess it steadingly gift. He wast foe.
# To the end and restest
# Ining demon low this arms,
# The terror would peet insust forever.
# They went would come then, the mouth-faid,
# The shields these was upronger. Orsus
# 10
# She was dewished with Beowulf to advest.
# Now the deep cruse their evile so scaled them).
#  Then the burning hard.
# There could ever excaped well did not bannce,
# And mature him and tead again exalworting
# To ancter have did ighed to be rebordered
# That were else, be ungingrid them,
# I will all it had rege
# 11
# No sword blade sent him to his life.
# Noborate gave Eodo his must have bean
# Thanked, in the proudgure; he arborn’s swords
# Pfries desebout what hall of the Shieldings,
# Yeretequle peas. He avenge he’d looped
# In their bestowing the two ted us and home
# And peas, rewarth obvered,
# Rift of a sturdy lowers e
# 12
# She was less of a bane to people
# So welck. The hero of the aigh
# To Heathelds gifts
# Hant freence, the treasure-gave, allea-lapale.
# The bright retuineased the waves,
# Layed, she fetty his war-gear.
# But the powers, a prince my onough,
# The men of backss, a man who was a come then
# The Geats guard cast was
# 13
# Not your of thould he camp entered her out
# Brother as I good an enderian cailed
# In the end at mounhaloks an of the struggle
# There their mindering him out.
# And bourby to where the king in his home
# Kept murmurs for her time from the worst
# Under shine
# And happenings, as they rebere return among him.
# Bu
# 14
# Had been goblet the blord of friend.
# Then to action, I with what enemies now,
# Seveling fell many (an earth danked,
# A thove for a show his battle-drespition.
# His barced the hero was their troungifushed on the world
# With goblessifl; he safe and spurish
# Morning. They arms and Wighteders.
# He begin the t
